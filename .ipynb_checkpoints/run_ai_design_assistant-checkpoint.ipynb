# %%
from learning_center import *
from matplotlib import pyplot as plt

# %%
runData = #specify runData directory

# %%
l = learning_center(runData = runData, cluster_anzahl = 16)
# Out:
# First Object: Retrain first:
# *** Start Retrain ***
# StateCounter runData path: /mnt/fs2/home/seyselein/ws/NN_Github/learning_model_public/runData_1000.
# Time taken for sorting and loading File-List: 4.842308282852173 seconds
# Time taken for loading: 1.298302412033081 seconds
# Loaded Tensors from  b1
# Time taken for sorting and loading File-List: 0.12021327018737793 seconds
# Time taken for loading: 1.2900619506835938 seconds
# Loaded Tensors from  b2
# Time taken for sorting and loading File-List: 0.11976289749145508 seconds
# Time taken for loading: 1.0226197242736816 seconds
# Loaded Tensors from  b3
# Time taken for sorting and loading File-List: 0.12045860290527344 seconds
# Time taken for loading: 1.069972276687622 seconds
# Loaded Tensors from  b4
# Time taken for sorting and loading File-List: 0.12008547782897949 seconds
# Time taken for loading: 1.0224480628967285 seconds
# Loaded Tensors from  b5
# Time taken for sorting and loading File-List: 0.11911892890930176 seconds
# Time taken for loading: 1.0997252464294434 seconds
# Loaded Tensors from  b6
# Time taken for sorting and loading File-List: 0.11986589431762695 seconds
# Time taken for loading: 1.0394351482391357 seconds
# Loaded Tensors from  b7
# Time taken for sorting and loading File-List: 0.11881542205810547 seconds
# Time taken for loading: 1.0924134254455566 seconds
# Loaded Tensors from  b8
# Final Scaling Factors: Channels: [1,2,3,4]
# [0.011169332913994783, 0.3874513296081335, 0.10034844128560476, 0.09539330579485293]
# Normalized Tensors.
# *** Loading Model clustering ***
# Pretrained: Loaded model_trained_b1.pth
# Pretrained: Loaded model_trained_b2.pth
# Pretrained: Loaded model_trained_b3.pth
# Pretrained: Loaded model_trained_b4.pth
# Pretrained: Loaded model_trained_b5.pth
# Pretrained: Loaded model_trained_b6.pth
# Pretrained: Loaded model_trained_b7.pth
# Pretrained: Loaded model_trained_b8.pth
# Got Latent Space Data. Delete Tensors...
# Cluster_Anzahl set to 16.
# Get Cluster IDs with SpectralClustering.
# Shape of Cluster_IDS_Assigned: (552, 8)
# [Amount of Individuals, Amount of FlowAreas]
# Fit-Grenze: Fitness Eta 40 Percent Quantile: 0.081.Fitness Eta Mean: 0.090. Max_ID: 1000
# Accuracy: 100.00% for area b1.
# Accuracy on Test-Data: 80.00% for area b1.
# Accuracy: 100.00% for area b2.
# Accuracy on Test-Data: 73.33% for area b2.
# Accuracy: 100.00% for area b3.
# Accuracy on Test-Data: 86.67% for area b3.
# Accuracy: 100.00% for area b4.
# Accuracy on Test-Data: 80.00% for area b4.
# Accuracy: 100.00% for area b5.
# Accuracy on Test-Data: 80.00% for area b5.
# Accuracy: 100.00% for area b6.
# Accuracy on Test-Data: 86.67% for area b6.
# Accuracy: 99.63% for area b7.
# Accuracy on Test-Data: 100.00% for area b7.
# Accuracy: 100.00% for area b8.
# Accuracy on Test-Data: 66.67% for area b8.
# *** Design Assisant Retraining Finished ***

# %% [markdown]
# #### Recommendation and Prediction based on DOFs: ####

# %%
case_id = 107
x = l.case_data[1][case_id - 1 ]
print(f"DOFs for Case-Id {case_id}.")
print("Recommendation for DOFs:")
recommend = l.recommend_sim([x])
# Out:
# DOFs for Case-Id 107.
# Recommendation for DOFs:
# EVAL CONTER = 1
# Gaussian Process with dim = 1.
# Recommend Sim: True. Known Cluster_ID: True. Gaussian Estimation: True.
# Predicted Fitness: [0.06513115 0.00154888 0.02414626]

# %% [markdown]
# #### Plot Pressure Field of Cluster-ID: ####

# %%
### you must reload Tensors for plotting ###
l.load_tensors()
# Out:
# StateCounter runData path: /mnt/fs2/home/seyselein/ws/NN_Github/learning_model_public/runData_1000.
# Time taken for sorting and loading File-List: 3.8635663986206055 seconds
# Time taken for loading: 1.0889830589294434 seconds
# Loaded Tensors from  b1
# Time taken for sorting and loading File-List: 0.11949014663696289 seconds
# Time taken for loading: 1.207385778427124 seconds
# Loaded Tensors from  b2
# Time taken for sorting and loading File-List: 0.12108087539672852 seconds
# Time taken for loading: 1.224471092224121 seconds
# Loaded Tensors from  b3
# Time taken for sorting and loading File-List: 0.12057042121887207 seconds
# Time taken for loading: 1.3127458095550537 seconds
# Loaded Tensors from  b4
# Time taken for sorting and loading File-List: 0.11888694763183594 seconds
# Time taken for loading: 1.1887767314910889 seconds
# Loaded Tensors from  b5
# Time taken for sorting and loading File-List: 0.12010669708251953 seconds
# Time taken for loading: 1.1922712326049805 seconds
# Loaded Tensors from  b6
# Time taken for sorting and loading File-List: 0.12067270278930664 seconds
# Time taken for loading: 1.1710422039031982 seconds
# Loaded Tensors from  b7
# Time taken for sorting and loading File-List: 0.12149286270141602 seconds
# Time taken for loading: 1.2035229206085205 seconds
# Loaded Tensors from  b8
# Final Scaling Factors: Channels: [1,2,3,4]
# [0.011169332913994783, 0.3874513296081335, 0.10034844128560476, 0.09539330579485293]
# Normalized Tensors.

# %%
cluster_id = l.cluster_ids_valued[0][2]
cluster_id
# Out:
# array([13,  4,  3, 10,  4,  9,  8, 13], dtype=int32)

# %%
l.plot_tensor_one(cluster_id)
